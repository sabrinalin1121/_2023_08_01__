# %%
import pandas as pd
data = {"字串":["台北", "台中"],
        "整數":[1000, 3000],
        "浮點數":[3.258, 7.396]}

df = pd.DataFrame(data)
display(df)
# Out:
#    字串    整數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化資料表
#pip install jinja2
df.style\
.format(precision=2,thousands=",",decimal=".")\
.relabel_index(["列1","列2"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_5285c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5285c_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_5285c_level0_col1" class="col_heading level0 col1" >整數</th>
#       <th id="T_5285c_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5285c_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_5285c_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_5285c_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_5285c_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_5285c_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_5285c_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_5285c_row1_col1" class="data row1 col1" >3,000</td>
#       <td id="T_5285c_row1_col2" class="data row1 col2" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
data = np.random.rand(10,2) * 5
df = pd.DataFrame(data,
                  index = pd.date_range(start="2023-09-01",periods=10),
                  columns=["台北","台中"]
                  )
df
# Out:
#                   台北        台中
# 2023-09-01  0.664770  0.327760
# 2023-09-02  4.928641  3.069286
# 2023-09-03  2.370876  2.941112
# 2023-09-04  1.254656  3.592032
# 2023-09-05  1.578491  4.943462
# 2023-09-06  2.130317  2.735591
# 2023-09-07  3.271265  4.127179
# 2023-09-08  3.241712  2.156256
# 2023-09-09  4.172937  4.004640
# 2023-09-10  3.211616  1.418761

# %%
#視覺美化資料表
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮溼"
    else:
        return "日照"
    
df.style\
.format(feel_condition)\
.set_caption("體感溫度")\
.background_gradient(cmap="PuBuGn",vmin=1,vmax=5,axis=None)
# Out:
# <style type="text/css">
# #T_16ca5_row0_col0, #T_16ca5_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_16ca5_row1_col0 {
#   background-color: #014b3a;
#   color: #f1f1f1;
# }
# #T_16ca5_row1_col1 {
#   background-color: #60a5cd;
#   color: #f1f1f1;
# }
# #T_16ca5_row2_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_16ca5_row2_col1 {
#   background-color: #6eabd0;
#   color: #f1f1f1;
# }
# #T_16ca5_row3_col0 {
#   background-color: #f5ecf5;
#   color: #000000;
# }
# #T_16ca5_row3_col1 {
#   background-color: #2d8db6;
#   color: #f1f1f1;
# }
# #T_16ca5_row4_col0 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_16ca5_row4_col1 {
#   background-color: #014a39;
#   color: #f1f1f1;
# }
# #T_16ca5_row5_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_16ca5_row5_col1 {
#   background-color: #88b3d5;
#   color: #000000;
# }
# #T_16ca5_row6_col0 {
#   background-color: #4c9bc7;
#   color: #f1f1f1;
# }
# #T_16ca5_row6_col1 {
#   background-color: #027b7d;
#   color: #f1f1f1;
# }
# #T_16ca5_row7_col0 {
#   background-color: #4f9dc8;
#   color: #f1f1f1;
# }
# #T_16ca5_row7_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_16ca5_row8_col0 {
#   background-color: #027978;
#   color: #f1f1f1;
# }
# #T_16ca5_row8_col1 {
#   background-color: #028189;
#   color: #f1f1f1;
# }
# #T_16ca5_row9_col0 {
#   background-color: #529ec9;
#   color: #f1f1f1;
# }
# #T_16ca5_row9_col1 {
#   background-color: #f0e6f2;
#   color: #000000;
# }
# </style>
# <table id="T_16ca5">
#   <caption>體感溫度</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16ca5_level0_col0" class="col_heading level0 col0" >台北</th>
#       <th id="T_16ca5_level0_col1" class="col_heading level0 col1" >台中</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16ca5_level0_row0" class="row_heading level0 row0" >2023-09-01 00:00:00</th>
#       <td id="T_16ca5_row0_col0" class="data row0 col0" >溫暖</td>
#       <td id="T_16ca5_row0_col1" class="data row0 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row1" class="row_heading level0 row1" >2023-09-02 00:00:00</th>
#       <td id="T_16ca5_row1_col0" class="data row1 col0" >日照</td>
#       <td id="T_16ca5_row1_col1" class="data row1 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row2" class="row_heading level0 row2" >2023-09-03 00:00:00</th>
#       <td id="T_16ca5_row2_col0" class="data row2 col0" >潮溼</td>
#       <td id="T_16ca5_row2_col1" class="data row2 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row3" class="row_heading level0 row3" >2023-09-04 00:00:00</th>
#       <td id="T_16ca5_row3_col0" class="data row3 col0" >溫暖</td>
#       <td id="T_16ca5_row3_col1" class="data row3 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row4" class="row_heading level0 row4" >2023-09-05 00:00:00</th>
#       <td id="T_16ca5_row4_col0" class="data row4 col0" >溫暖</td>
#       <td id="T_16ca5_row4_col1" class="data row4 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row5" class="row_heading level0 row5" >2023-09-06 00:00:00</th>
#       <td id="T_16ca5_row5_col0" class="data row5 col0" >潮溼</td>
#       <td id="T_16ca5_row5_col1" class="data row5 col1" >潮溼</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row6" class="row_heading level0 row6" >2023-09-07 00:00:00</th>
#       <td id="T_16ca5_row6_col0" class="data row6 col0" >日照</td>
#       <td id="T_16ca5_row6_col1" class="data row6 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row7" class="row_heading level0 row7" >2023-09-08 00:00:00</th>
#       <td id="T_16ca5_row7_col0" class="data row7 col0" >日照</td>
#       <td id="T_16ca5_row7_col1" class="data row7 col1" >潮溼</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row8" class="row_heading level0 row8" >2023-09-09 00:00:00</th>
#       <td id="T_16ca5_row8_col0" class="data row8 col0" >日照</td>
#       <td id="T_16ca5_row8_col1" class="data row8 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_16ca5_level0_row9" class="row_heading level0 row9" >2023-09-10 00:00:00</th>
#       <td id="T_16ca5_row9_col0" class="data row9 col0" >日照</td>
#       <td id="T_16ca5_row9_col1" class="data row9 col1" >溫暖</td>
#     </tr>
#   </tbody>
# </table>

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5))
df.style\
.hide(subset=[0, 2, 4],axis=0)\
.hide(subset=[1,3],axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_66aa9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66aa9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_66aa9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_66aa9_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66aa9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66aa9_row1_col0" class="data row1 col0" >0.029614</td>
#       <td id="T_66aa9_row1_col2" class="data row1 col2" >0.369333</td>
#       <td id="T_66aa9_row1_col4" class="data row1 col4" >-0.234826</td>
#     </tr>
#     <tr>
#       <th id="T_66aa9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66aa9_row3_col0" class="data row3 col0" >3.368169</td>
#       <td id="T_66aa9_row3_col2" class="data row3 col2" >0.356056</td>
#       <td id="T_66aa9_row3_col4" class="data row3 col4" >2.541465</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(np.random.randn(10,4),
             columns=["A", "B", "C", "D"])
display(df)

def style_negative(v, props=''):
    return props if v < 0 else None

df.style\
.map(style_negative,props='color:red;')
# Out:
#           A         B         C         D
# 0  0.734613  0.251793  0.369641 -0.748660
# 1 -0.835041 -0.609379  1.451621  1.015824
# 2  1.187025  0.279804  0.486854  0.457669
# 3 -0.537111 -0.614671  0.740028  0.804740
# 4  1.045205 -1.568906  0.627941  0.900765
# 5 -0.403869  0.317028 -0.438641 -0.465782
# 6  1.071002 -2.384764 -1.716605  0.172738
# 7  0.359840 -1.153156 -0.522859 -0.028951
# 8  0.100804 -1.715714  1.170813 -0.126853
# 9 -0.226970  1.357702 -3.450399  0.725061
# <style type="text/css">
# #T_a7d4b_row0_col3, #T_a7d4b_row1_col0, #T_a7d4b_row1_col1, #T_a7d4b_row3_col0, #T_a7d4b_row3_col1, #T_a7d4b_row4_col1, #T_a7d4b_row5_col0, #T_a7d4b_row5_col2, #T_a7d4b_row5_col3, #T_a7d4b_row6_col1, #T_a7d4b_row6_col2, #T_a7d4b_row7_col1, #T_a7d4b_row7_col2, #T_a7d4b_row7_col3, #T_a7d4b_row8_col1, #T_a7d4b_row8_col3, #T_a7d4b_row9_col0, #T_a7d4b_row9_col2 {
#   color: red;
# }
# </style>
# <table id="T_a7d4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7d4b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a7d4b_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_a7d4b_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_a7d4b_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7d4b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7d4b_row0_col0" class="data row0 col0" >0.734613</td>
#       <td id="T_a7d4b_row0_col1" class="data row0 col1" >0.251793</td>
#       <td id="T_a7d4b_row0_col2" class="data row0 col2" >0.369641</td>
#       <td id="T_a7d4b_row0_col3" class="data row0 col3" >-0.748660</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7d4b_row1_col0" class="data row1 col0" >-0.835041</td>
#       <td id="T_a7d4b_row1_col1" class="data row1 col1" >-0.609379</td>
#       <td id="T_a7d4b_row1_col2" class="data row1 col2" >1.451621</td>
#       <td id="T_a7d4b_row1_col3" class="data row1 col3" >1.015824</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7d4b_row2_col0" class="data row2 col0" >1.187025</td>
#       <td id="T_a7d4b_row2_col1" class="data row2 col1" >0.279804</td>
#       <td id="T_a7d4b_row2_col2" class="data row2 col2" >0.486854</td>
#       <td id="T_a7d4b_row2_col3" class="data row2 col3" >0.457669</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7d4b_row3_col0" class="data row3 col0" >-0.537111</td>
#       <td id="T_a7d4b_row3_col1" class="data row3 col1" >-0.614671</td>
#       <td id="T_a7d4b_row3_col2" class="data row3 col2" >0.740028</td>
#       <td id="T_a7d4b_row3_col3" class="data row3 col3" >0.804740</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7d4b_row4_col0" class="data row4 col0" >1.045205</td>
#       <td id="T_a7d4b_row4_col1" class="data row4 col1" >-1.568906</td>
#       <td id="T_a7d4b_row4_col2" class="data row4 col2" >0.627941</td>
#       <td id="T_a7d4b_row4_col3" class="data row4 col3" >0.900765</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a7d4b_row5_col0" class="data row5 col0" >-0.403869</td>
#       <td id="T_a7d4b_row5_col1" class="data row5 col1" >0.317028</td>
#       <td id="T_a7d4b_row5_col2" class="data row5 col2" >-0.438641</td>
#       <td id="T_a7d4b_row5_col3" class="data row5 col3" >-0.465782</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a7d4b_row6_col0" class="data row6 col0" >1.071002</td>
#       <td id="T_a7d4b_row6_col1" class="data row6 col1" >-2.384764</td>
#       <td id="T_a7d4b_row6_col2" class="data row6 col2" >-1.716605</td>
#       <td id="T_a7d4b_row6_col3" class="data row6 col3" >0.172738</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a7d4b_row7_col0" class="data row7 col0" >0.359840</td>
#       <td id="T_a7d4b_row7_col1" class="data row7 col1" >-1.153156</td>
#       <td id="T_a7d4b_row7_col2" class="data row7 col2" >-0.522859</td>
#       <td id="T_a7d4b_row7_col3" class="data row7 col3" >-0.028951</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a7d4b_row8_col0" class="data row8 col0" >0.100804</td>
#       <td id="T_a7d4b_row8_col1" class="data row8 col1" >-1.715714</td>
#       <td id="T_a7d4b_row8_col2" class="data row8 col2" >1.170813</td>
#       <td id="T_a7d4b_row8_col3" class="data row8 col3" >-0.126853</td>
#     </tr>
#     <tr>
#       <th id="T_a7d4b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a7d4b_row9_col0" class="data row9 col0" >-0.226970</td>
#       <td id="T_a7d4b_row9_col1" class="data row9 col1" >1.357702</td>
#       <td id="T_a7d4b_row9_col2" class="data row9 col2" >-3.450399</td>
#       <td id="T_a7d4b_row9_col3" class="data row9 col3" >0.725061</td>
#     </tr>
#   </tbody>
# </table>
